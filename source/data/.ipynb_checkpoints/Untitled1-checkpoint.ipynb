# %%
library(tidyverse)
faithful <- as_tibble(faithful)
# faithful
write_csv(faithful, "faithful.csv")

# %%
morley <- as_tibble(morley)
morley
write_csv(morley, "morley.csv")
# Out:
#     Expt Run Speed
# 1   1     1   850
# 2   1     2   740
# 3   1     3   900
# 4   1     4  1070
# 5   1     5   930
# 6   1     6   850
# 7   1     7   950
# 8   1     8   980
# 9   1     9   980
# 10  1    10   880
# 11  1    11  1000
# 12  1    12   980
# 13  1    13   930
# 14  1    14   650
# 15  1    15   760
# 16  1    16   810
# 17  1    17  1000
# 18  1    18  1000
# 19  1    19   960
# 20  1    20   960
# 21  2     1   960
# 22  2     2   940
# 23  2     3   960
# 24  2     4   940
# 25  2     5   880
# 26  2     6   800
# 27  2     7   850
# 28  2     8   880
# 29  2     9   900
# 30  2    10   840
# ⋮   ⋮    ⋮   ⋮
# 71  4    11  910
# 72  4    12  920
# 73  4    13  890
# 74  4    14  860
# 75  4    15  880
# 76  4    16  720
# 77  4    17  840
# 78  4    18  850
# 79  4    19  850
# 80  4    20  780
# 81  5     1  890
# 82  5     2  840
# 83  5     3  780
# 84  5     4  810
# 85  5     5  760
# 86  5     6  810
# 87  5     7  790
# 88  5     8  810
# 89  5     9  820
# ...

# %%
# Out:
# Error in parse(text = x, srcfile = src): <text>:1:35: unexpected symbol
# 1: morley_hist = alt.Chart(morley_df).mark_bar
#                                       ^
# Traceback:
